# %%
# Import necessay library
from __future__ import print_function

import os
import subprocess

from IPython.display import Image, display

from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.naive_bayes import GaussianNB
from sklearn.cross_validation import train_test_split
from sklearn.externals.six import StringIO

import pandas as pd
import numpy as np

import statistics
import pydot

# %%
# Function to encode target into integer
def encode_target(df, target_column, encoded_target_column_name):
    """Add column to df with integers for the target.

    Args
    ----
    df -- pandas DataFrame.
    target_column -- column to map to int, producing
                     new Target column.
    encoded_target_column_name -- new Target column

    Returns
    -------
    df_mod -- modified DataFrame.
    targets -- list of target names.
    """
    df_mod = df.copy()
    targets = df_mod[target_column].unique()
    map_to_int = {name: n for n, name in enumerate(targets)}
    df_mod[encoded_target_column_name] = df_mod[target_column].replace(map_to_int)

    return (df_mod, targets)

# %%
def create_tree(dt, features):
    dot_data = StringIO()
    export_graphviz(dt, out_file=dot_data,  
                    feature_names=features,
                    filled=True, rounded=True,  
                    special_characters=True)
    graph = pydot.graph_from_dot_data(dot_data.getvalue())
    return graph.create_png()

# %%
def get_code(tree, feature_names, target_names,
             spacer_base="    "):
    """Produce psuedo-code for decision tree.

    Args
    ----
    tree -- scikit-leant DescisionTree.
    feature_names -- list of feature names.
    target_names -- list of target (class) names.
    spacer_base -- used for spacing code (default: "    ").

    Notes
    -----
    based on http://stackoverflow.com/a/30104792.
    """
    left      = tree.tree_.children_left
    right     = tree.tree_.children_right
    threshold = tree.tree_.threshold
    features  = [feature_names[i] for i in tree.tree_.feature]
    value = tree.tree_.value

    def recurse(left, right, threshold, features, node, depth):
        spacer = spacer_base * depth
        if (threshold[node] != -2):
            print(spacer + "if " + features[node] + " <= " + str(threshold[node]) + " :")
            if left[node] != -1:
                    recurse(left, right, threshold, features,
                            left[node], depth+1)
            print(spacer + "else :")
            if right[node] != -1:
                    recurse(left, right, threshold, features,
                            right[node], depth+1)
        else:
            target = value[node]
            for i, v in zip(np.nonzero(target)[1],
                            target[np.nonzero(target)]):
                target_name = target_names[i]
                target_count = int(v)
                print(spacer + "return " + str(target_name) + \
                      " (count=" + str(target_count) + ")")

    recurse(left, right, threshold, features, 0, 0)

# %%
file_csv = "1_beasiswa.csv"

# Define class (target) and features
# Column 0 = IPK
# Column 1 = Tingkat Kemiskinan
target_column = "Perolehan Beasiswa"
feature_columns = [0,1]

# %%
# Read data from csv
file_csv = file_csv.replace(".csv", "")
df = pd.read_csv(file_csv + ".csv")

# %%
# Define list of accuracy to be calculated its mean
accuracies = []

# Iterate 10 times, from 1 to 11
for iter in range(1,11):
    # Encode target (class) as unique integer
    df, targets = encode_target(df, target_column, target_column + " Encoded")
    
    # Select features (predictors)
    features = list(df.columns[feature_columns])
    
    # Create data train and test
    # Data test size = 30% of all data
    train, test = train_test_split(df, test_size = 0.3)
    
    # Print data train and data test
    print("Data latih iterasi ke-%s" % iter)
    print("------------------------")
    print(train)
    print("\r\n")
    print("Data uji iterasi ke-%s" % iter)
    print("------------------------")
    print(test)
    print("\r\n")
    
    # Save data train and data test for each iteration for report
    train.to_csv(file_csv + "_train_" + str(iter) + ".csv")
    test.to_csv(file_csv + "_test_" + str(iter) + ".csv")
    
    # Use train data to construct model
    # Define target and features column
    y = train[target_column + " Encoded"]
    X = train[features]
    
    # Construct model
    # criterion = gini -> features are continues
    # criterion = entropy -> features are categorical
    # dt = GaussianNB()
    dt = DecisionTreeClassifier(criterion="gini")
    dt.fit(X, y)
    
    # Get code for model
    print("Code iterasi ke-%s" % iter)
    print("------------------------")
    get_code(dt, features, targets)
    print("\r\n")
    
    # Construct tree image
    print("Grafik Tree iterasi ke-%s" % iter)
    print("------------------------")
    tree_image = create_tree(dt, features)
    display(Image(tree_image))
    print("\r\n")
    
    # Check acuracy of the model using test data
    y = test[target_column + " Encoded"]
    X = test[features]
    accuracy = dt.score(X,y)
    accuracies.append(accuracy)
    
    # Print accuracy
    print("Akurasi iterasi ke-%s : %s" % (iter, accuracy))
    print("---------------------------")
    print("\r\n")
    
    # Print separator
    print("========================================================")
    print("\r\n")

# Print the mean of accuracies of all iterations
accuracy_mean = statistics.mean(accuracies)
print("Rata-rata akurasi dari %s kali percobaan : %s" % (len(range(1,11)), accuracy_mean))
# Out:
# Data latih iterasi ke-1
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 1   1.2                 1.0        Tidak Dapat                           0
# 5   2.5                 3.0              Dapat                           1
# 6   3.0                 2.5              Dapat                           1
# 0   0.8                 0.8        Tidak Dapat                           0
# 3   2.0                 1.5        Tidak Dapat                           0
# 10  2.5                 3.5              Dapat                           1
# 8   3.0                 3.0              Dapat                           1
#
#
# Data uji iterasi ke-1
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 7  3.0                 2.0              Dapat                           1
# 4  0.7                 1.5        Tidak Dapat                           0
# 9  3.5                 3.9              Dapat                           1
# 2  1.0                 1.2        Tidak Dapat                           0
#
#
# Code iterasi ke-1
# ------------------------
# if IPK <= 2.25 :
#     return Tidak Dapat (count=3)
# else :
#     return Dapat (count=4)
#
#
# Grafik Tree iterasi ke-1
# ------------------------
# Akurasi iterasi ke-1 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-2
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 5   2.5                 3.0              Dapat                           1
# 0   0.8                 0.8        Tidak Dapat                           0
# 1   1.2                 1.0        Tidak Dapat                           0
# 7   3.0                 2.0              Dapat                           1
# 6   3.0                 2.5              Dapat                           1
# 8   3.0                 3.0              Dapat                           1
# 10  2.5                 3.5              Dapat                           1
#
#
# Data uji iterasi ke-2
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 9  3.5                 3.9              Dapat                           1
# 4  0.7                 1.5        Tidak Dapat                           0
# 3  2.0                 1.5        Tidak Dapat                           0
# 2  1.0                 1.2        Tidak Dapat                           0
#
#
# Code iterasi ke-2
# ------------------------
# if Tingkat Kemiskinan <= 1.5 :
#     return Tidak Dapat (count=2)
# else :
#     return Dapat (count=5)
#
#
# Grafik Tree iterasi ke-2
# ------------------------
# Akurasi iterasi ke-2 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-3
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 6   3.0                 2.5              Dapat                           1
# 9   3.5                 3.9              Dapat                           1
# 0   0.8                 0.8        Tidak Dapat                           0
# 10  2.5                 3.5              Dapat                           1
# 8   3.0                 3.0              Dapat                           1
# 1   1.2                 1.0        Tidak Dapat                           0
# 7   3.0                 2.0              Dapat                           1
#
#
# Data uji iterasi ke-3
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 4  0.7                 1.5        Tidak Dapat                           0
# 5  2.5                 3.0              Dapat                           1
# 3  2.0                 1.5        Tidak Dapat                           0
# 2  1.0                 1.2        Tidak Dapat                           0
#
#
# Code iterasi ke-3
# ------------------------
# if IPK <= 1.85000002384 :
#     return Tidak Dapat (count=2)
# else :
#     return Dapat (count=5)
#
#
# Grafik Tree iterasi ke-3
# ------------------------
# Akurasi iterasi ke-3 : 0.75
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-4
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 10  2.5                 3.5              Dapat                           1
# 0   0.8                 0.8        Tidak Dapat                           0
# 2   1.0                 1.2        Tidak Dapat                           0
# 6   3.0                 2.5              Dapat                           1
# 3   2.0                 1.5        Tidak Dapat                           0
# 1   1.2                 1.0        Tidak Dapat                           0
# 4   0.7                 1.5        Tidak Dapat                           0
#
#
# Data uji iterasi ke-4
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 5  2.5                 3.0              Dapat                           1
# 9  3.5                 3.9              Dapat                           1
# 7  3.0                 2.0              Dapat                           1
# 8  3.0                 3.0              Dapat                           1
#
#
# Code iterasi ke-4
# ------------------------
# if IPK <= 2.25 :
#     return Tidak Dapat (count=5)
# else :
#     return Dapat (count=2)
#
#
# Grafik Tree iterasi ke-4
# ------------------------
# Akurasi iterasi ke-4 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-5
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 2   1.0                 1.2        Tidak Dapat                           0
# 8   3.0                 3.0              Dapat                           1
# 9   3.5                 3.9              Dapat                           1
# 4   0.7                 1.5        Tidak Dapat                           0
# 3   2.0                 1.5        Tidak Dapat                           0
# 5   2.5                 3.0              Dapat                           1
# 10  2.5                 3.5              Dapat                           1
#
#
# Data uji iterasi ke-5
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 1  1.2                 1.0        Tidak Dapat                           0
# 0  0.8                 0.8        Tidak Dapat                           0
# 7  3.0                 2.0              Dapat                           1
# 6  3.0                 2.5              Dapat                           1
#
#
# Code iterasi ke-5
# ------------------------
# if IPK <= 2.25 :
#     return Tidak Dapat (count=3)
# else :
#     return Dapat (count=4)
#
#
# Grafik Tree iterasi ke-5
# ------------------------
# Akurasi iterasi ke-5 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-6
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 1  1.2                 1.0        Tidak Dapat                           0
# 7  3.0                 2.0              Dapat                           1
# 0  0.8                 0.8        Tidak Dapat                           0
# 5  2.5                 3.0              Dapat                           1
# 3  2.0                 1.5        Tidak Dapat                           0
# 4  0.7                 1.5        Tidak Dapat                           0
# 6  3.0                 2.5              Dapat                           1
#
#
# Data uji iterasi ke-6
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 2   1.0                 1.2        Tidak Dapat                           0
# 8   3.0                 3.0              Dapat                           1
# 9   3.5                 3.9              Dapat                           1
# 10  2.5                 3.5              Dapat                           1
#
#
# Code iterasi ke-6
# ------------------------
# if Tingkat Kemiskinan <= 1.75 :
#     return Tidak Dapat (count=4)
# else :
#     return Dapat (count=3)
#
#
# Grafik Tree iterasi ke-6
# ------------------------
# Akurasi iterasi ke-6 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-7
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 1   1.2                 1.0        Tidak Dapat                           0
# 7   3.0                 2.0              Dapat                           1
# 8   3.0                 3.0              Dapat                           1
# 3   2.0                 1.5        Tidak Dapat                           0
# 10  2.5                 3.5              Dapat                           1
# 5   2.5                 3.0              Dapat                           1
# 9   3.5                 3.9              Dapat                           1
#
#
# Data uji iterasi ke-7
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 6  3.0                 2.5              Dapat                           1
# 0  0.8                 0.8        Tidak Dapat                           0
# 4  0.7                 1.5        Tidak Dapat                           0
# 2  1.0                 1.2        Tidak Dapat                           0
#
#
# Code iterasi ke-7
# ------------------------
# if IPK <= 2.25 :
#     return Tidak Dapat (count=2)
# else :
#     return Dapat (count=5)
#
#
# Grafik Tree iterasi ke-7
# ------------------------
# Akurasi iterasi ke-7 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-8
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 4   0.7                 1.5        Tidak Dapat                           0
# 10  2.5                 3.5              Dapat                           1
# 5   2.5                 3.0              Dapat                           1
# 9   3.5                 3.9              Dapat                           1
# 7   3.0                 2.0              Dapat                           1
# 6   3.0                 2.5              Dapat                           1
# 1   1.2                 1.0        Tidak Dapat                           0
#
#
# Data uji iterasi ke-8
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 8  3.0                 3.0              Dapat                           1
# 2  1.0                 1.2        Tidak Dapat                           0
# 0  0.8                 0.8        Tidak Dapat                           0
# 3  2.0                 1.5        Tidak Dapat                           0
#
#
# Code iterasi ke-8
# ------------------------
# if Tingkat Kemiskinan <= 1.75 :
#     return Tidak Dapat (count=2)
# else :
#     return Dapat (count=5)
#
#
# Grafik Tree iterasi ke-8
# ------------------------
# Akurasi iterasi ke-8 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-9
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 8   3.0                 3.0              Dapat                           1
# 10  2.5                 3.5              Dapat                           1
# 5   2.5                 3.0              Dapat                           1
# 6   3.0                 2.5              Dapat                           1
# 7   3.0                 2.0              Dapat                           1
# 2   1.0                 1.2        Tidak Dapat                           0
# 3   2.0                 1.5        Tidak Dapat                           0
#
#
# Data uji iterasi ke-9
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 0  0.8                 0.8        Tidak Dapat                           0
# 1  1.2                 1.0        Tidak Dapat                           0
# 4  0.7                 1.5        Tidak Dapat                           0
# 9  3.5                 3.9              Dapat                           1
#
#
# Code iterasi ke-9
# ------------------------
# if Tingkat Kemiskinan <= 1.75 :
#     return Tidak Dapat (count=2)
# else :
#     return Dapat (count=5)
#
#
# Grafik Tree iterasi ke-9
# ------------------------
# Akurasi iterasi ke-9 : 1.0
# ---------------------------
#
#
# ========================================================
#
#
# Data latih iterasi ke-10
# ------------------------
#     IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 2   1.0                 1.2        Tidak Dapat                           0
# 1   1.2                 1.0        Tidak Dapat                           0
# 10  2.5                 3.5              Dapat                           1
# 6   3.0                 2.5              Dapat                           1
# 7   3.0                 2.0              Dapat                           1
# 5   2.5                 3.0              Dapat                           1
# 4   0.7                 1.5        Tidak Dapat                           0
#
#
# Data uji iterasi ke-10
# ------------------------
#    IPK  Tingkat Kemiskinan Perolehan Beasiswa  Perolehan Beasiswa Encoded
# 3  2.0                 1.5        Tidak Dapat                           0
# 0  0.8                 0.8        Tidak Dapat                           0
# 9  3.5                 3.9              Dapat                           1
# 8  3.0                 3.0              Dapat                           1
#
#
# Code iterasi ke-10
# ------------------------
# if IPK <= 1.85000002384 :
#     return Tidak Dapat (count=3)
# else :
#     return Dapat (count=4)
#
#
# Grafik Tree iterasi ke-10
# ------------------------
# Akurasi iterasi ke-10 : 0.75
# ---------------------------
#
#
# ========================================================
#
#
# Rata-rata akurasi dari 10 kali percobaan : 0.95
