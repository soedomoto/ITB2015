# %%
from __future__ import print_function

import os
import subprocess

import statistics
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.cross_validation import train_test_split
from sklearn.externals.six import StringIO 
import pydot
from IPython.display import Image, display

# %%
# Read csv
df = pd.read_csv("Beasiswa.csv")

# %%
def encode_target(df, target_column):
    """Add column to df with integers for the target.

    Args
    ----
    df -- pandas DataFrame.
    target_column -- column to map to int, producing
                     new Target column.

    Returns
    -------
    df_mod -- modified DataFrame.
    targets -- list of target names.
    """
    df_mod = df.copy()
    targets = df_mod[target_column].unique()
    map_to_int = {name: n for n, name in enumerate(targets)}
    df_mod["Target"] = df_mod[target_column].replace(map_to_int)

    return (df_mod, targets)

# %%
# Define list of accuracy to be calculated
accuracies = []

for iter in range(1,11):
    # Encode target (classes) as unique integer
    df, targets = encode_target(df, "Perolehan Beasiswa")
    
    # Select features (predictors)
    features = list(df.columns[:2])
    
    # Create data train and test
    train, test = train_test_split(df, test_size = 0.3)
    
    # Print data train and data test
    print("Data latih iterasi ke-%s" % iter)
    print(train)
    print("\r\n")
    print("Data uji iterasi ke-%s" % iter)
    print(test)
    print("\r\n")
    
    # Construct the tree
    y = train["Target"]
    X = train[features]
    dt = DecisionTreeClassifier(min_samples_split=4, max_features=1, random_state=99)
    dt.fit(X, y)
    
    # Show the tree
    print("Grafik Tree iterasi ke-%s" % iter)
    dot_data = StringIO()
    export_graphviz(dt, out_file=dot_data,  
                    feature_names=features,
                    filled=True, rounded=True,  
                    special_characters=True)
    graph = pydot.graph_from_dot_data(dot_data.getvalue())
    display(Image(graph.create_png()))
    print("\r\n")
    
    # Use test data to check accuracy of the model
    y = test["Target"]
    X = test[features]
    accuracy = dt.score(X,y)
    accuracies.append(accuracy)
    
    # Print accuracy
    print("Akurasi iterasi ke-%s : %s" % (iter, accuracy))
    print("\r\n")
    
    # Print separator
    print("========================================================")
    print("\r\n")

# Print the mean of accuracies of all iterations
accuracy_mean = statistics.mean(accuracies)
print("Rata-rata akurasi dari %s kali percobaan : %s" % (len(range(1,11)), accuracy_mean))
# Out:
# Data latih iterasi ke-1
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 5   2.5                 3.0                   1       1
# 9   3.5                 3.9                   1       1
# 8   3.0                 3.0                   1       1
# 10  2.5                 3.5                   1       1
# 6   3.0                 2.5                   1       1
# 7   3.0                 2.0                   1       1
# 1   1.2                 1.0                   0       0
#
#
# Data uji iterasi ke-1
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 0  0.8                 0.8                   0       0
# 4  0.7                 1.5                   0       0
# 2  1.0                 1.2                   0       0
# 3  2.0                 1.5                   0       0
#
#
# Grafik Tree iterasi ke-1
# Akurasi iterasi ke-1 : 0.75
#
#
# ========================================================
#
#
# Data latih iterasi ke-2
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 0  0.8                 0.8                   0       0
# 4  0.7                 1.5                   0       0
# 3  2.0                 1.5                   0       0
# 5  2.5                 3.0                   1       1
# 1  1.2                 1.0                   0       0
# 8  3.0                 3.0                   1       1
# 9  3.5                 3.9                   1       1
#
#
# Data uji iterasi ke-2
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 6   3.0                 2.5                   1       1
# 10  2.5                 3.5                   1       1
# 7   3.0                 2.0                   1       1
# 2   1.0                 1.2                   0       0
#
#
# Grafik Tree iterasi ke-2
# Akurasi iterasi ke-2 : 1.0
#
#
# ========================================================
#
#
# Data latih iterasi ke-3
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 7  3.0                 2.0                   1       1
# 9  3.5                 3.9                   1       1
# 3  2.0                 1.5                   0       0
# 0  0.8                 0.8                   0       0
# 8  3.0                 3.0                   1       1
# 2  1.0                 1.2                   0       0
# 4  0.7                 1.5                   0       0
#
#
# Data uji iterasi ke-3
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 10  2.5                 3.5                   1       1
# 1   1.2                 1.0                   0       0
# 5   2.5                 3.0                   1       1
# 6   3.0                 2.5                   1       1
#
#
# Grafik Tree iterasi ke-3
# Akurasi iterasi ke-3 : 0.5
#
#
# ========================================================
#
#
# Data latih iterasi ke-4
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 2  1.0                 1.2                   0       0
# 4  0.7                 1.5                   0       0
# 8  3.0                 3.0                   1       1
# 1  1.2                 1.0                   0       0
# 0  0.8                 0.8                   0       0
# 6  3.0                 2.5                   1       1
# 9  3.5                 3.9                   1       1
#
#
# Data uji iterasi ke-4
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 10  2.5                 3.5                   1       1
# 7   3.0                 2.0                   1       1
# 5   2.5                 3.0                   1       1
# 3   2.0                 1.5                   0       0
#
#
# Grafik Tree iterasi ke-4
# Akurasi iterasi ke-4 : 1.0
#
#
# ========================================================
#
#
# Data latih iterasi ke-5
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 9   3.5                 3.9                   1       1
# 3   2.0                 1.5                   0       0
# 5   2.5                 3.0                   1       1
# 6   3.0                 2.5                   1       1
# 10  2.5                 3.5                   1       1
# 2   1.0                 1.2                   0       0
# 8   3.0                 3.0                   1       1
#
#
# Data uji iterasi ke-5
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 1  1.2                 1.0                   0       0
# 0  0.8                 0.8                   0       0
# 7  3.0                 2.0                   1       1
# 4  0.7                 1.5                   0       0
#
#
# Grafik Tree iterasi ke-5
# Akurasi iterasi ke-5 : 1.0
#
#
# ========================================================
#
#
# Data latih iterasi ke-6
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 9  3.5                 3.9                   1       1
# 4  0.7                 1.5                   0       0
# 2  1.0                 1.2                   0       0
# 1  1.2                 1.0                   0       0
# 8  3.0                 3.0                   1       1
# 6  3.0                 2.5                   1       1
# 5  2.5                 3.0                   1       1
#
#
# Data uji iterasi ke-6
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 0   0.8                 0.8                   0       0
# 7   3.0                 2.0                   1       1
# 10  2.5                 3.5                   1       1
# 3   2.0                 1.5                   0       0
#
#
# Grafik Tree iterasi ke-6
# Akurasi iterasi ke-6 : 0.75
#
#
# ========================================================
#
#
# Data latih iterasi ke-7
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 1  1.2                 1.0                   0       0
# 7  3.0                 2.0                   1       1
# 0  0.8                 0.8                   0       0
# 4  0.7                 1.5                   0       0
# 3  2.0                 1.5                   0       0
# 9  3.5                 3.9                   1       1
# 2  1.0                 1.2                   0       0
#
#
# Data uji iterasi ke-7
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 10  2.5                 3.5                   1       1
# 5   2.5                 3.0                   1       1
# 8   3.0                 3.0                   1       1
# 6   3.0                 2.5                   1       1
#
#
# Grafik Tree iterasi ke-7
# Akurasi iterasi ke-7 : 0.5
#
#
# ========================================================
#
#
# Data latih iterasi ke-8
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 4   0.7                 1.5                   0       0
# 10  2.5                 3.5                   1       1
# 2   1.0                 1.2                   0       0
# 6   3.0                 2.5                   1       1
# 9   3.5                 3.9                   1       1
# 5   2.5                 3.0                   1       1
# 3   2.0                 1.5                   0       0
#
#
# Data uji iterasi ke-8
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 8  3.0                 3.0                   1       1
# 0  0.8                 0.8                   0       0
# 7  3.0                 2.0                   1       1
# 1  1.2                 1.0                   0       0
#
#
# Grafik Tree iterasi ke-8
# Akurasi iterasi ke-8 : 1.0
#
#
# ========================================================
#
#
# Data latih iterasi ke-9
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 5  2.5                 3.0                   1       1
# 3  2.0                 1.5                   0       0
# 8  3.0                 3.0                   1       1
# 1  1.2                 1.0                   0       0
# 0  0.8                 0.8                   0       0
# 6  3.0                 2.5                   1       1
# 7  3.0                 2.0                   1       1
#
#
# Data uji iterasi ke-9
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 2   1.0                 1.2                   0       0
# 9   3.5                 3.9                   1       1
# 10  2.5                 3.5                   1       1
# 4   0.7                 1.5                   0       0
#
#
# Grafik Tree iterasi ke-9
# Akurasi iterasi ke-9 : 1.0
#
#
# ========================================================
#
#
# Data latih iterasi ke-10
#     IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 7   3.0                 2.0                   1       1
# 0   0.8                 0.8                   0       0
# 6   3.0                 2.5                   1       1
# 10  2.5                 3.5                   1       1
# 1   1.2                 1.0                   0       0
# 5   2.5                 3.0                   1       1
# 9   3.5                 3.9                   1       1
#
#
# Data uji iterasi ke-10
#    IPK  Tingkat Kemiskinan  Perolehan Beasiswa  Target
# 3  2.0                 1.5                   0       0
# 8  3.0                 3.0                   1       1
# 4  0.7                 1.5                   0       0
# 2  1.0                 1.2                   0       0
#
#
# Grafik Tree iterasi ke-10
# Akurasi iterasi ke-10 : 0.75
#
#
# ========================================================
#
#
# Rata-rata akurasi dari 10 kali percobaan : 0.825
